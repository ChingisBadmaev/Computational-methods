# %% [markdown]
# # Градиентные методы для выпуклой оптимизации

# %%
import math
from IPython.display import Image

# %% [markdown]
# # Тестовые данные

# %% [markdown]
# ### 1. y = x ** 2 + 4

# %%
Image(filename = "test1.png", width = 300)

# %%
def f_1(x):
    return x ** 2 + 4

# %%
def gradient_1(x):
    return 2 * x

# %% [markdown]
# ### 2. y = 150 * sin(x / 15) + 7

# %%
Image(filename = "test2.png", width = 400)

# %%
def f_2(x):
    return 150 * math.sin(x / 15) + 7

# %%
def gradient_2(x):
    return 10 * math.cos(x / 15)

# %% [markdown]
# ### Градиентный спуск

# %%
def gradient_descent(x_old, eps):
    k = 3
    x_new = x_old - gradient_2(x_old)
    while abs(x_new - x_old) > eps:
        x_old = x_new
        x_new = x_old - gradient_2(x_old) / k
        k += 1
    answer = [x_new, f_2(x_new), k]
    return answer

# %% [markdown]
# # Вывод данных

# %%
def pr(x, epsilon):
    print('x = ', gradient_descent(x, epsilon)[0])
    print('y = ', gradient_descent(x, epsilon)[1])
    print('k = ', gradient_descent(x, epsilon)[2])

# %% [markdown]
# ## 1. y = x ** 2

# %%
pr(500, 10e-5)
# Out:
# x =  541.2245087744772
# y =  -142.8365918084978
# k =  4669

# %% [markdown]
# ### Проверка на правильность работы алгоритма

# %%
Image(filename = "test1.2.png", width = 800)

# %% [markdown]
# ## 2. y = 150 * sin(x / 15) + 7

# %%
pr(20, 10e-5)
# Out:
# x =  -22.669421463197185
# y =  -142.73454563632183
# k =  5949

# %% [markdown]
# ### Проверка на правильность работы алгоритма

# %%
Image(filename = "test2.2.png", width = 800)
